# %% [markdown]
# # Week 1 — Python for AI
#
# ## Day 1
#
# Goal: Become comfortable reading and modifying Python used in AI notebooks.

# %%
def greet(name:str)-> str:
    return f"hello, {name} future AI Engineer"

greet("Zain ul abideen") # I called it using the name as a parameter sending zain as an argument to the function greet. The function greet will return a string "hello, zain future AI Engineer"
# Out:
# 'hello, Zain ul abideen future AI Engineer'

# %%
import sys
print(sys.version) # This will print the version of python that is being used in the current environment.
# Out:
# 3.14.7 (main, Aug 10 2026, 00:00:00) [GCC 15.3.1 20260722 (Red Hat 15.3.1-1)]

# %%
print(sys.executable) # This will print the path of the python executable that is being used in the current environment.
# Out:
# /home/zain/Applied-AI/applied-ai-bootcamp/.venv/bin/python
